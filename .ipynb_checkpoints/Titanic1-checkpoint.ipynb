# %%
import pandas as pd
data_train = pd.read_csv("train.csv")

# %%
data_train.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
import seaborn

# %%
import pytorch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-d35c46f8d1a2> in <module>()
# ----> 1 import pytorch
#
# ModuleNotFoundError: No module named 'pytorch'

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
import numpy as np

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import pandas as pd
data_test = pd.read_csv("test.csv")

# %%
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data_test.count()
# Out:
# PassengerId    418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
data_train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data_train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                            Name  \
# count    891.000000  891.000000  891.000000                             891
# unique          NaN         NaN         NaN                             891
# top             NaN         NaN         NaN  McDermott, Miss. Brigdet Delia
# freq            NaN         NaN         NaN                               1
# mean     446.000000    0.383838    2.308642                             NaN
# std      257.353842    0.486592    0.836071                             NaN
# min        1.000000    0.000000    1.000000                             NaN
# 25%      223.500000    0.000000    2.000000                             NaN
# 50%      446.000000    0.000000    3.000000                             NaN
# 75%      668.500000    1.000000    3.000000                             NaN
# max      891.000000    1.000000    3.000000                             NaN
#
#          Sex         Age       SibSp       Parch Ticket        Fare  \
# count    891  714.000000  891.000000  891.000000    891  891.000000
# unique     2         NaN         NaN         NaN    681         NaN
# top     male         NaN         NaN         NaN   1601         NaN
# freq     577         NaN         NaN         NaN      7         NaN
# mean     NaN   29.699118    0.523008    0.381594    NaN   32.204208
# std      NaN   14.526497    1.102743    0.806057    NaN   49.693429
# min      NaN    0.420000    0.000000    0.000000    NaN    0.000000
# 25%      NaN   20.125000    0.000000    0.000000    NaN    7.910400
# 50%      NaN   28.000000    0.000000    0.000000    NaN   14.454200
# 75%      NaN   38.000000    1.000000    0.000000    NaN   31.000000
# max      NaN   80.000000    8.000000    6.000000    NaN  512.329200
#
#               Cabin Embarked
# count           204      889
# unique          147        3
# top     C23 C25 C27        S
# freq              4      644
# mean            NaN      NaN
# std             NaN      NaN
# min             NaN      NaN
# 25%             NaN      NaN
# 50%             NaN      NaN
# 75%             NaN      NaN
# max             NaN      NaN

# %%
data_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(pd.isnull(data_train).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pd.isnull(data_train).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pd.isnull(data_test).sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data_train.SibSp.max()
# Out:
# 8

# %%
sns.barplot(x="Sex", y="Survived", data = data_train)

# %%
data_train.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
print("Percentage of females who survived:", data_train["Survived"][data_train["Sex"] == 'female'].value_counts()
# Out:
#   File "<ipython-input-33-b5f93528fefa>", line 1
#     print("Percentage of females who survived:", data_train["Survived"][data_train["Sex"] == 'female'].value_counts()
#                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
data_train["Survived"][data_train["Sex"] == 'male'].count()
# Out:
# 577

# %%
data_train.Sex.count()
# Out:
# 891

# %%
data_train.Sex.count()
# Out:
# 891

# %%
data_train.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
data_train["Sex"] == 'male'.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-84be8c258e54> in <module>()
# ----> 1 data_train["Sex"] == 'male'.count()
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
(data_train["Sex"] == 'female').count()
# Out:
# 891

# %%
data_train["Survived"][data_train["Sex"] == 'male'].count()
# Out:
# 577

# %%
data_train["Survived"][data_train["Sex"] == 'male'].sum()
# Out:
# 109

# %%
data_train.groupby(['Sex']).count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
data_train.groupby(['Sex', 'Survived']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex    Survived
# female 0                  81      81    81   64     81     81      81    81
#        1                 233     233   233  197    233    233     233   233
# male   0                 468     468   468  360    468    468     468   468
#        1                 109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Sex    Survived
# female 0             6        81
#        1            91       231
# male   0            62       468
#        1            45       109

# %%
data_train.groupby(['Sex', 'Survived']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex    Survived
# female 0                  81      81    81   64     81     81      81    81
#        1                 233     233   233  197    233    233     233   233
# male   0                 468     468   468  360    468    468     468   468
#        1                 109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Sex    Survived
# female 0             6        81
#        1            91       231
# male   0            62       468
#        1            45       109

# %%
(data_train["Sex"] == 'male').count()
# Out:
# 891

# %%
import pandasql as sq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-88-c6e507ca3208> in <module>()
# ----> 1 import pandasql as sq
#
# ModuleNotFoundError: No module named 'pandasql'

# %%
(data_train["Sex"] == 'male').count()
# Out:
# 891

# %%
(data_train["Sex"] == 'female').sum()
# Out:
# 577

# %%
data_train["Survived"][data_train["Sex"] == 'female'].sum()
# Out:
# 233

# %%
data_train.groupby(['Sex', 'Survived'])['PassengerId'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
sns.barplot(x="Sex", y="Survived", data = data_train)

# %%
print("Percentage of females who survived:", data_train["Survived"][datatrain["Sex"] == 'female'].value_counts(normalize = True)[1]*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-f5cbdf48127f> in <module>()
# ----> 1 print("Percentage of females who survived:", data_train["Survived"][datatrain["Sex"] == 'female'].value_counts(normalize = True)[1]*100)
#
# NameError: name 'datatrain' is not defined

# %%
print("Percentage of females who survived:", data_train["Survived"][data_train["Sex"] == 'female'].value_counts()[1]*100)
# Out:
# Percentage of females who survived: 23300

# %%
print("Percentage of females who survived:", data_train["Survived"][data_train["Sex"] == 'female'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095

# %%
print("Percentage of females who survived:", data_train["Survived"][data_train["Sex"] == 'female'].value_counts(normalize = True))
# Out:
# Percentage of females who survived: 1    0.742038
# 0    0.257962
# Name: Survived, dtype: float64

# %%
data_train["Survived"][data_train["Sex"] == 'female'].sum()
# Out:
# 233

# %%
(data_train["Survived"][data_train["Sex"] == 'female').sum()
# Out:
#   File "<ipython-input-122-3202f39ddd29>", line 1
#     (data_train["Survived"][data_train["Sex"] == 'female').sum()
#                                                          ^
# SyntaxError: invalid syntax

# %%
(data_train["Sex"] == 'female').sum()
# Out:
# 314

# %%
data_train["Survived"][data_train["Sex"] == 'female'.sum()
# Out:
# 233

# %%
data_train.Survived[data_train["Sex"] == 'female'].sum()/(data_train["Sex"] == 'female').sum()
# Out:
# 0.7420382165605095

# %%
data_train.Sex.count()
# Out:
# 891

# %%
data_train.Sex=='female'.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-d7ec17c0775a> in <module>()
# ----> 1 data_train.Sex=='female'.sum()
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
data_train.groupby(['Sex','Survived'])['PassengerId'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
data_train["Survived"][data_train["Sex"] == 'female'].sum()
# Out:
# 233

# %%
data_train['Survived'][data_train['Sex'] == 'female'].sum()
# Out:
# 233

# %%
(data_train['Sex']=='female').sum()
# Out:
# 314

# %%
data_train['Survived'][data_train['Sex'] == 'female'].sum()/(data_train['Sex']=='female').sum()
# Out:
# 0.7420382165605095

# %%
data_train.Survived[data_train["Sex"] == 'female'].sum()/(data_train["Sex"] == 'female').sum()
# Out:
# 0.7420382165605095

# %%
data_train["Survived"][data_train["Sex"] == 'female'].value_counts()[1]
# Out:
# 233

# %%
data_train["Survived"][data_train["Sex"] == 'female'].value_counts()
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
sns.barplot(x= "Parch", y = "Survived", data = data_train
           )

# %%
data_train.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data_train["Age"] = data_train["Age"].fillna(-0.5)

bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
data_train['AgeGroup'] = pd.cut(data_train["Age"], bins, labels = labels)


#draw a bar plot of Age vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=data_train)

# %%
sns.barplot(x="Age", y="Survived", data=data_train)

# %%
bins = [-1, 0, 5, 12, 18, 24, 35, 60]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
data_train['AgeGroup'] = pd.cut(data_train["Age"], bins, labels = labels)

sns.barplot(x="AgeGroup", y="Survived", data=data_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-844e1925ca28> in <module>()
#       1 bins = [-1, 0, 5, 12, 18, 24, 35, 60]
#       2 labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
# ----> 3 data_train['AgeGroup'] = pd.cut(data_train["Age"], bins, labels = labels)
#       4
#       5 sns.barplot(x="AgeGroup", y="Survived", data=data_train)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest)
#     134                               precision=precision,
#     135                               include_lowest=include_lowest,
# --> 136                               dtype=dtype)
#     137
#     138     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     252         else:
#     253             if len(labels) != len(bins) - 1:
# --> 254                 raise ValueError('Bin labels must be one fewer than '
#     255                                  'the number of bin edges')
#     256         if not is_categorical_dtype(labels):
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
data_train['AgeGroup'] = pd.cut(data_train["Age"], bins, labels = labels)


#draw a bar plot of Age vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=data_train)

# %%
bins = [-1, 0, 5, 12, 18, 24, 35, 60, 70]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
data_train['AgeGroup'] = pd.cut(data_train["Age"], bins, labels = labels)


#draw a bar plot of Age vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=data_train)

# %%
data_test.describe(include="all")
# Out:
#         PassengerId      Pclass                      Name   Sex         Age  \
# count    418.000000  418.000000                       418   418  332.000000
# unique          NaN         NaN                       418     2         NaN
# top             NaN         NaN  Midtsjo, Mr. Karl Albert  male         NaN
# freq            NaN         NaN                         1   266         NaN
# mean    1100.500000    2.265550                       NaN   NaN   30.272590
# std      120.810458    0.841838                       NaN   NaN   14.181209
# min      892.000000    1.000000                       NaN   NaN    0.170000
# 25%      996.250000    1.000000                       NaN   NaN   21.000000
# 50%     1100.500000    3.000000                       NaN   NaN   27.000000
# 75%     1204.750000    3.000000                       NaN   NaN   39.000000
# max     1309.000000    3.000000                       NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %%
data_train["Survived"][data_train["Cabin"] == 1].value_counts(normalize = True)
# Out:
# Series([], Name: Survived, dtype: float64)

# %%
data_train["CabinBool"] = (data_train["Cabin"].notnull().astype('int'))
data_train["Survived"][data_train["CabinBool"] == 1].value_counts(normalize = True)
# Out:
# 1    0.666667
# 0    0.333333
# Name: Survived, dtype: float64

# %%
data_train["CabinBool"] = data_train.Cabin.notnull().astype('int')
data_train["Survived"][data_train["CabinBool"] == 1].value_counts(normalize = True)
# Out:
# 1    0.666667
# 0    0.333333
# Name: Survived, dtype: float64

# %%
data_train["Cabin"]
# Out:
# 0              NaN
# 1              C85
# 2              NaN
# 3             C123
# 4              NaN
# 5              NaN
# 6              E46
# 7              NaN
# 8              NaN
# 9              NaN
# 10              G6
# 11            C103
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             D56
# 22             NaN
# 23              A6
# 24             NaN
# 25             NaN
# 26             NaN
# 27     C23 C25 C27
# 28             NaN
# 29             NaN
#           ...
# 861            NaN
# 862            D17
# 863            NaN
# 864            NaN
# 865            NaN
# 866            NaN
# 867            A24
# 868            NaN
# 869            NaN
# 870            NaN
# 871            D35
# 872    B51 B53 B55
# 873            NaN
# 874            NaN
# 875            NaN
# 876            NaN
# 877            NaN
# 878            NaN
# 879            C50
# 880            NaN
# 881            NaN
# 882            NaN
# 883            NaN
# 884            NaN
# 885            NaN
# 886            NaN
# 887            B42
# 888            NaN
# 889           C148
# 890            NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data_train.Cabin
# Out:
# 0              NaN
# 1              C85
# 2              NaN
# 3             C123
# 4              NaN
# 5              NaN
# 6              E46
# 7              NaN
# 8              NaN
# 9              NaN
# 10              G6
# 11            C103
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             D56
# 22             NaN
# 23              A6
# 24             NaN
# 25             NaN
# 26             NaN
# 27     C23 C25 C27
# 28             NaN
# 29             NaN
#           ...
# 861            NaN
# 862            D17
# 863            NaN
# 864            NaN
# 865            NaN
# 866            NaN
# 867            A24
# 868            NaN
# 869            NaN
# 870            NaN
# 871            D35
# 872    B51 B53 B55
# 873            NaN
# 874            NaN
# 875            NaN
# 876            NaN
# 877            NaN
# 878            NaN
# 879            C50
# 880            NaN
# 881            NaN
# 882            NaN
# 883            NaN
# 884            NaN
# 885            NaN
# 886            NaN
# 887            B42
# 888            NaN
# 889           C148
# 890            NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data_train.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male  -0.5      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male  -0.5      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female  -0.5      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male  -0.5      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  -0.5      0
# 29                                 Todoroff, Mr. Lalio    male  -0.5      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  -0.5      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male  -0.5      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male  -0.5      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  -0.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked     AgeGroup  \
# 0        0         A/5 21171    7.2500          NaN        S      Student
# 1        0          PC 17599   71.2833          C85        C        Adult
# 2        0  STON/O2. 3101282    7.9250          NaN        S  Young Adult
# 3        0            113803   53.1000         C123        S  Young Adult
# 4        0            373450    8.0500          NaN        S  Young Adult
# 5        0            330877    8.4583          NaN        Q      Unknown
# 6        0             17463   51.8625          E46        S        Adult
# 7        1            349909   21.0750          NaN        S         Baby
# 8        2            347742   11.1333          NaN        S  Young Adult
# 9        0            237736   30.0708          NaN        C     Teenager
# 10       1           PP 9549   16.7000           G6        S         Baby
# 11       0            113783   26.5500         C103        S        Adult
# 12       0         A/5. 2151    8.0500          NaN        S      Student
# 13       5            347082   31.2750          NaN        S        Adult
# 14       0            350406    7.8542          NaN        S     Teenager
# 15       0            248706   16.0000          NaN        S        Adult
# 16       1            382652   29.1250          NaN        Q         Baby
# 17       0            244373   13.0000          NaN        S      Unknown
# 18       0            345763   18.0000          NaN        S  Young Adult
# 19       0              2649    7.2250          NaN        C      Unknown
# 20       0            239865   26.0000          NaN        S  Young Adult
# 21       0            248698   13.0000          D56        S  Young Adult
# 22       0            330923    8.0292          NaN        Q     Teenager
# 23       0            113788   35.5000           A6        S  Young Adult
# 24       1            349909   21.0750          NaN        S        Child
# 25       5            347077   31.3875          NaN        S        Adult
# 26       0              2631    7.2250          NaN        C      Unknown
# 27       2             19950  263.0000  C23 C25 C27        S      Student
# 28       0            330959    7.8792          NaN        Q      Unknown
# 29       0            349216    7.8958          NaN        S      Unknown
# ..     ...               ...       ...          ...      ...          ...
# 861      0             28134   11.5000          NaN        S      Student
# 862      0             17466   25.9292          D17        S        Adult
# 863      2          CA. 2343   69.5500          NaN        S      Unknown
# 864      0            233866   13.0000          NaN        S      Student
# 865      0            236852   13.0000          NaN        S        Adult
# 866      0     SC/PARIS 2149   13.8583          NaN        C  Young Adult
# 867      0          PC 17590   50.4958          A24        S  Young Adult
# 868      0            345777    9.5000          NaN        S      Unknown
# 869      1            347742   11.1333          NaN        S         Baby
# 870      0            349248    7.8958          NaN        S  Young Adult
# 871      1             11751   52.5542          D35        S        Adult
# 872      0               695    5.0000  B51 B53 B55        S  Young Adult
# 873      0            345765    9.0000          NaN        S        Adult
# 874      0         P/PP 3381   24.0000          NaN        C  Young Adult
# 875      0              2667    7.2250          NaN        C     Teenager
# 876      0              7534    9.8458          NaN        S      Student
# 877      0            349212    7.8958          NaN        S      Student
# 878      0            349217    7.8958          NaN        S      Unknown
# 879      1             11767   83.1583          C50        C        Adult
# 880      1            230433   26.0000          NaN        S  Young Adult
# 881      0            349257    7.8958          NaN        S  Young Adult
# 882      0              7552   10.5167          NaN        S      Student
# 883      0  C.A./SOTON 34068   10.5000          NaN        S  Young Adult
# 884      0   SOTON/OQ 392076    7.0500          NaN        S  Young Adult
# 885      5            382652   29.1250          NaN        Q        Adult
# 886      0            211536   13.0000          NaN        S  Young Adult
# 887      0            112053   30.0000          B42        S      Student
# 888      2        W./C. 6607   23.4500          NaN        S      Unknown
# 889      0            111369   30.0000         C148        C  Young Adult
# 890      0            370376    7.7500          NaN        Q  Young Adult
#
#      CabinBool
# 0            0
# 1            1
# 2            0
# 3            1
# 4            0
# 5            0
# 6            1
# 7            0
# 8            0
# 9            0
# 10           1
# 11           1
# 12           0
# 13           0
# 14           0
# 15           0
# 16           0
# 17           0
# 18           0
# 19           0
# 20           0
# 21           1
# 22           0
# 23           1
# 24           0
# 25           0
# 26           0
# 27           1
# 28           0
# 29           0
# ..         ...
# 861          0
# 862          1
# 863          0
# 864          0
# 865          0
# 866          0
# 867          1
# 868          0
# 869          0
# 870          0
# 871          1
# 872          1
# 873          0
# 874          0
# 875          0
# 876          0
# 877          0
# 878          0
# 879          1
# 880          0
# 881          0
# 882          0
# 883          0
# 884          0
# 885          0
# 886          0
# 887          1
# 888          0
# 889          1
# 890          0
#
# [891 rows x 14 columns]>

# %%
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     AgeGroup  CabinBool
# 0      0         A/5 21171   7.2500   NaN        S      Student          0
# 1      0          PC 17599  71.2833   C85        C        Adult          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Young Adult          0
# 3      0            113803  53.1000  C123        S  Young Adult          1
# 4      0            373450   8.0500   NaN        S  Young Adult          0

# %%
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  CabinBool
# 0  34.5      0      0   330911   7.8292   NaN        Q          0
# 1  47.0      1      0   363272   7.0000   NaN        S          0
# 2  62.0      0      0   240276   9.6875   NaN        Q          0
# 3  27.0      0      0   315154   8.6625   NaN        S          0
# 4  22.0      1      1  3101298  12.2875   NaN        S          0

# %%
data_test["CabinBool1"] = (data_test["Cabin"].notnull().astype())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-5bf8db3c77d0> in <module>()
# ----> 1 data_test["CabinBool1"] = (data_test["Cabin"].notnull().astype())
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# TypeError: astype() missing 1 required positional argument: 'dtype'

# %%
data_train.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
print("Number of people embarking in Southampton (S):")
southampton = data_train[data_train["Embarked"] == "S"].shape[0]
print(southampton)
# Out:
# Number of people embarking in Southampton (S):
# 644

# %%
(data_train['Embarked']=='S').sum()
# Out:
# 644

# %%
(data_train['Embarked']=='C').sum()
# Out:
# 168

# %%
(data_train['Embarked']=='NaN').sum()
# Out:
# 0

# %%
data_train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# AgeGroup       886
# CabinBool      891
# dtype: int64

# %%
pd.isnull(data_train).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# AgeGroup         5
# CabinBool        0
# dtype: int64

# %%
data_train = data_train.fillna({"Embarked": "S"})

# %%
pd.isnull(data_train).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# AgeGroup         5
# CabinBool        0
# dtype: int64

# %%
data_train.drop(["Cabin"], axis =1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male  -0.5      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male  -0.5      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female  -0.5      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male  -0.5      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  -0.5      0
# 29                                 Todoroff, Mr. Lalio    male  -0.5      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  -0.5      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male  -0.5      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male  -0.5      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  -0.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare Embarked     AgeGroup  CabinBool
# 0        0         A/5 21171    7.2500        S      Student          0
# 1        0          PC 17599   71.2833        C        Adult          1
# 2        0  STON/O2. 3101282    7.9250        S  Young Adult          0
# 3        0            113803   53.1000        S  Young Adult          1
# 4        0            373450    8.0500        S  Young Adult          0
# 5        0            330877    8.4583        Q      Unknown          0
# 6        0             17463   51.8625        S        Adult          1
# 7        1            349909   21.0750        S         Baby          0
# 8        2            347742   11.1333        S  Young Adult          0
# 9        0            237736   30.0708        C     Teenager          0
# 10       1           PP 9549   16.7000        S         Baby          1
# 11       0            113783   26.5500        S        Adult          1
# 12       0         A/5. 2151    8.0500        S      Student          0
# 13       5            347082   31.2750        S        Adult          0
# 14       0            350406    7.8542        S     Teenager          0
# 15       0            248706   16.0000        S        Adult          0
# 16       1            382652   29.1250        Q         Baby          0
# 17       0            244373   13.0000        S      Unknown          0
# 18       0            345763   18.0000        S  Young Adult          0
# 19       0              2649    7.2250        C      Unknown          0
# 20       0            239865   26.0000        S  Young Adult          0
# 21       0            248698   13.0000        S  Young Adult          1
# 22       0            330923    8.0292        Q     Teenager          0
# 23       0            113788   35.5000        S  Young Adult          1
# 24       1            349909   21.0750        S        Child          0
# 25       5            347077   31.3875        S        Adult          0
# 26       0              2631    7.2250        C      Unknown          0
# 27       2             19950  263.0000        S      Student          1
# 28       0            330959    7.8792        Q      Unknown          0
# 29       0            349216    7.8958        S      Unknown          0
# ..     ...               ...       ...      ...          ...        ...
# 861      0             28134   11.5000        S      Student          0
# 862      0             17466   25.9292        S        Adult          1
# 863      2          CA. 2343   69.5500        S      Unknown          0
# 864      0            233866   13.0000        S      Student          0
# 865      0            236852   13.0000        S        Adult          0
# 866      0     SC/PARIS 2149   13.8583        C  Young Adult          0
# 867      0          PC 17590   50.4958        S  Young Adult          1
# 868      0            345777    9.5000        S      Unknown          0
# 869      1            347742   11.1333        S         Baby          0
# 870      0            349248    7.8958        S  Young Adult          0
# 871      1             11751   52.5542        S        Adult          1
# 872      0               695    5.0000        S  Young Adult          1
# 873      0            345765    9.0000        S        Adult          0
# 874      0         P/PP 3381   24.0000        C  Young Adult          0
# 875      0              2667    7.2250        C     Teenager          0
# 876      0              7534    9.8458        S      Student          0
# 877      0            349212    7.8958        S      Student          0
# 878      0            349217    7.8958        S      Unknown          0
# 879      1             11767   83.1583        C        Adult          1
# 880      1            230433   26.0000        S  Young Adult          0
# 881      0            349257    7.8958        S  Young Adult          0
# 882      0              7552   10.5167        S      Student          0
# 883      0  C.A./SOTON 34068   10.5000        S  Young Adult          0
# 884      0   SOTON/OQ 392076    7.0500        S  Young Adult          0
# 885      5            382652   29.1250        Q        Adult          0
# 886      0            211536   13.0000        S  Young Adult          0
# 887      0            112053   30.0000        S      Student          1
# 888      2        W./C. 6607   23.4500        S      Unknown          0
# 889      0            111369   30.0000        C  Young Adult          1
# 890      0            370376    7.7500        Q  Young Adult          0
#
# [891 rows x 13 columns]

# %%
pd.isnull(data_train).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# AgeGroup         5
# CabinBool        0
# dtype: int64

# %%
data_train = data_train.drop(["Cabin"], axis =1)

# %%
pd.isnull(data_train).sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# AgeGroup       5
# CabinBool      0
# dtype: int64

# %%
#https://www.kaggle.com/nadintamer/titanic-survival-predictions-beginner/notebook
